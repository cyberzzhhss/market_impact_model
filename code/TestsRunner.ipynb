# %%
from impactModel import FileManager

from impactModel.FirstPriceBuckets import FirstPriceBuckets
from impactModel.LastPriceBuckets import LastPriceBuckets

from dbReaders import FileNames
from dbReaders.TAQTradesReader import TAQTradesReader
from dbReaders.TAQQuotesReader import TAQQuotesReader

import os

# %%
# !python3 Test_FileManager.py
# !python3 Test_FirstPriceBuckets.py
# !python3 Test_LastPriceBuckets.py
# !python3 Test_Regression.py
# !python3 Test_ReturnBuckets.py
# !python3 Test_TickTest.py
# !python3 Test_UpdateMatrices.py
# !python3 Test_VWAP.py
# Out:
# Finished
# .
# ----------------------------------------------------------------------
# Ran 1 test in 0.075s
#
# OK
# .
# ----------------------------------------------------------------------
# Ran 1 test in 0.071s
#
# OK
# .
# ----------------------------------------------------------------------
# Ran 1 test in 0.000s
#
# OK
# .
# ----------------------------------------------------------------------
# Ran 1 test in 0.002s
#
# OK
# .
# ----------------------------------------------------------------------
# Ran 1 test in 0.145s
#
# OK
# ..
# ----------------------------------------------------------------------
# Ran 2 tests in 0.076s
#
# OK
# .
# ----------------------------------------------------------------------
# Ran 1 test in 0.105s
#
# OK
# There were 23595 trades and a VWAP price of 106.497133
# .
# ----------------------------------------------------------------------
# Ran 1 test in 0.046s
#
# OK
